# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: dask in /Users/shadowclone/Documents/BDA696/code/venv/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (2024.9.0)
# Requirement already satisfied: nltk in /Users/shadowclone/Documents/BDA696/code/venv/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (3.9.1)
# Requirement already satisfied: graphviz in /Users/shadowclone/Documents/BDA696/code/venv/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (0.20.3)
# Requirement already satisfied: click>=8.1 in /Users/shadowclone/Documents/BDA696/code/venv/lib/python3.12/site-packages (from dask->-r requirements.txt (line 1)) (8.1.7)
# Requirement already satisfied: cloudpickle>=3.0.0 in /Users/shadowclone/Documents/BDA696/code/venv/lib/python3.12/site-packages (from dask->-r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in /Users/shadowclone/Documents/BDA696/code/venv/lib/python3.12/site-packages (from dask->-r requirements.txt (line 1)) (2024.9.0)
# Requirement already satisfied: packaging>=20.0 in /Users/shadowclone/Documents/BDA696/code/venv/lib/python3.12/site-packages (from dask->-r requirements.txt (line 1)) (24.1)
# Requirement already satisfied: partd>=1.4.0 in /Users/shadowclone/Documents/BDA696/code/venv/lib/python3.12/site-packages (from dask->-r requirements.txt (line 1)) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/shadowclone/Documents/BDA696/code/venv/lib/python3.12/site-packages (from dask->-r requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /Users/shadowclone/Documents/BDA696/code/venv/lib/python3.12/site-packages (from dask->-r requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: joblib in /Users/shadowclone/Documents/BDA696/code/venv/lib/python3.12/site-packages (from nltk->-r requirements.txt (line 2)) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/shadowclone/Documents/BDA696/code/venv/lib/python3.12/site-packages (from nltk->-r requirements.txt (line 2)) (2024.9.11)
# Requirement already satisfied: tqdm in /Users/shadowclone/Documents/BDA696/code/venv/lib/python3.12/site-packages (from nltk->-r requirements.txt (line 2)) (4.66.5)
# Requirement already satisfied: locket in /Users/shadowclone/Documents/BDA696/code/venv/lib/python3.12/site-packages (from partd>=1.4.0->dask->-r requirements.txt (line 1)) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import dask.dataframe as dd
import dask.array as da
from dask import delayed, compute

import pandas as pd
import numpy as np

# Import natural language library
import nltk
from nltk.corpus import wordnet

nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/shadowclone/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Suppress scientific notations for large float values
pd.options.display.float_format = '{:.0f}'.format

# %% [markdown]
# ## Import our Data

# %%
movies_df = dd.read_csv(
    'movies.csv',
    blocksize = '25MB',
    sample = 500
)

movies_pd = movies_df.compute()

# %% [markdown]
# ## Missing Value Calculation

# %%
task_missing = movies_df.isnull().sum()
task_missing.visualize(engine = "cytoscape")
# Out:
# CytoscapeWidget(cytoscape_layout={'name': 'dagre', 'rankDir': 'BT', 'nodeSep': 10, 'edgeSep': 10, 'spacingFact…

# %%
task_missing.compute()
# Out:
# Unnamed: 0                 0
# id                         0
# title                      0
# genres                     0
# original_language          0
# overview                 489
# popularity                 0
# production_companies    2197
# release_date             266
# budget                     0
# revenue                    0
# runtime                   81
# status                     0
# tagline                 5129
# vote_average               0
# vote_count                 0
# credits                  324
# keywords                4010
# poster_path              785
# backdrop_path           3385
# recommendations         6623
# release_date_new         266
# dtype: int64

# %% [markdown]
# ## Extracting Datetime features from Strings

# %%
movies_df['release_date'].head(5)
movies_df.reset_index()
movies_df['release_date_dt'] = dd.to_datetime(
    movies_df['release_date'], errors = 'coerce',
    exact = False, format = '%Y-%m-%d'
)

# %%
movies_df.head(10)

# %% [markdown]
# ## Engineer Year, Month and Day of the week String features

# %%
movies_df['year'] = movies_df['release_date_dt'].dt.strftime('%Y')  # year
movies_df['month'] = movies_df['release_date_dt'].dt.strftime('%b') # Abbreviated name of month
movies_df['day_of_week'] = movies_df['release_date_dt'].dt.strftime('%a')   # Abbreviated day of the week

# %% [markdown]
# ## Filter by Datetime intervals & Sort the data

# %%
# %%time

# Filter by time index between 2016 and 2024
filtered_df = movies_df.loc[
    (movies_df['release_date_dt'] > '2015-12-31') & (movies_df['release_date_dt'] < '2024'), :
].compute().sort_values(['budget', 'release_date_dt'], ascending=False)

print(f'Number of matching observations - {len(filtered_df)}')
filtered_df.head(5)
# Out:
# Number of matching observations - 2539
# CPU times: user 257 ms, sys: 18.1 ms, total: 275 ms
# Wall time: 332 ms
#     Unnamed: 0      id                                  title  \
# 6           77  616037                 Thor: Love and Thunder
# 27         335  508943                                   Luca
# 83        1491  508439                                 Onward
# 28         341  384018  Fast & Furious Presents: Hobbs & Shaw
# 25         296  436969                      The Suicide Squad
#
#                                               genres original_language  \
# 6                              fantasy-action-comedy                en
# 27  animation-comedy-family-fantasy-action-adventure                en
# 83  family-animation-adventure-comedy-fantasy-action                en
# 28                           action-adventure-comedy                en
# 25                           action-comedy-adventure                en
#
#                                              overview  popularity  \
# 6   After his retirement is interrupted by Gorr th...     394.087
# 27  Luca and his best friend Alberto experience an...     132.456
# 83  In a suburban fantasy world two teenage elf br...      47.176
# 28  Ever since US Diplomatic Security Service Agen...     130.097
# 25  Supervillains Harley Quinn Bloodsport Peacemak...     144.638
#
#                                  production_companies release_date  \
# 6              Marvel Studios-Kevin Feige Productions   2022-07-06
# 27                         Pixar-Walt Disney Pictures   2021-06-17
# 83                         Walt Disney Pictures-Pixar   2020-02-29
# 28  Universal Pictures-Chris Morgan Productions-Se...   2019-08-01
# 25  DC Films-Atlas Entertainment-The Safran Compan...   2021-07-28
#
#          budget  ...                                            credits  \
# 6   250000000.0  ...  Chris Hemsworth-Natalie Portman-Christian Bale...
# 27  200000000.0  ...  Jacob Tremblay-Jack Dylan Grazer-Emma Berman-S...
# 83  200000000.0  ...  Tom Holland-Chris Pratt-Julia Louis-Dreyfus-Oc...
# 28  200000000.0  ...  Dwayne Johnson-Jason Statham-Idris Elba-Vaness...
# 25  185000000.0  ...  Margot Robbie-Idris Elba-John Cena-Joel Kinnam...
#
#                                              keywords  \
# 6   ex-girlfriend-hero-greek mythology-sequel-supe...
# 27  italy-monster-friendship-friends-coming of age...
# 83  elves-magic-dead father-dead parent-fantasy wo...
# 28  london england-biological weapon-secret organi...
# 25  monster-anti hero-secret mission-superhero-bas...
#
#                          poster_path                     backdrop_path  \
# 6   /pIkRyD18kl4FhoCNQuWxWu5cBLM.jpg  /jsoz1HlxczSuTx0mDl2h0lxy36l.jpg
# 27  /8tABCBpzu3mZbzMB3sRzMEHEvJi.jpg  /620hnMVLu6RSZW6a5rwO8gqpt0t.jpg
# 83  /f4aul3FyD3jv3v4bul1IrkWZvzq.jpg  /xFxk4vnirOtUxpOEWgA1MCRfy6J.jpg
# 28  /qRyy2UmjC5ur9bDi3kpNNRCc5nc.jpg  /hpgda6P9GutvdkDX5MUJ92QG9aj.jpg
# 25   /kb4s0ML0iVZlG6wAKbbs9NAm6X.jpg  /jlGmlFOcfo8n5tURmhC7YVd4Iyy.jpg
#
#                                       recommendations  release_date_new  \
# 6   539681-610150-985939-629176-2-45920-438148-782...        2022-07-06
# 27  527774-77742-79233-337404-800409-497698-400216...        2021-06-17
# 83  726166-662018-872325-611059-1038789-579955-454...        2020-02-29
# 28  337339-429617-458156-423204-420818-168259-9615...        2019-08-01
# 25  451048-497698-385128-550988-193414-566525-7913...        2021-07-28
#
#    release_date_dt  year month day_of_week
# 6       2022-07-06  2022   Jul         Wed
# 27      2021-06-17  2021   Jun         Thu
# 83      2020-02-29  2020   Feb         Sat
# 28      2019-08-01  2019   Aug         Thu
# 25      2021-07-28  2021   Jul         Wed
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Aggregate Total Budget by Year

# %%
# %%time

# Aggregation by year to find the total sum of movie budgets and sorted the pandas series
budget_summation = movies_df.groupby('year').agg({'budget': 'sum'}).sort_values(['budget'], ascending = False)

budget_summation.head(10)
# Out:
# CPU times: user 245 ms, sys: 15.3 ms, total: 261 ms
# Wall time: 267 ms
#          budget
# year
# 2013 1141692969
# 2016 1126213907
# 2022 1108167602
# 2017 1098264623
# 2010 1097269021
# 2019 1031065618
# 2003  929983303
# 2014  859188496
# 2002  857081750
# 2012  794552769

# %% [markdown]
# ## Text Mining for Movie Descriptions

# %%
def find_synonyms(word_list: list) :
    all_matches = []

    for word in word_list :
        synonyms = []
        word_nltk = wordnet.synsets(word)
        for synonym in word_nltk :
            for lemma in synonym.lemmas():
                name = str(lemma.name())
                name = name.replace('-', '')
                synonyms.append(name)

        synonym_set = list(set(synonyms))
        all_matches.extend(synonym_set)

    # flat_list = []
    # for sublist in all_matches:
    #     for element in sublist:
    #         flat_list.append(element)

    return all_matches

# %%
synonym_list = find_synonyms(['happy', 'joy', 'nice', 'good'])

# %% [markdown]
# ## Search for matching movie generes

# %%
# %%time

# Converting strings to all lower case
movies_df['genres'] = movies_df['genres'].str.lower()

# Concat list of synanyms into one string, seperated by '|'
synonym_string = '|'.join('synonym_list')

# String based matching search
feel_good_df = movies_df.loc[movies_df['genres'].str.contains(synonym_string), :]

filtered_movies_df = feel_good_df.compute().sort_values(['popularity'], ascending=False)
filtered_movies_df
# Out:
# CPU times: user 263 ms, sys: 13.3 ms, total: 276 ms
# Wall time: 277 ms
#       Unnamed: 0      id                                              title  \
# 0             12  594767                           Shazam! Fury of the Gods
# 1             18  615656                                  Meg 2: The Trench
# 2             19  868759                                            Ghosted
# 3             22  758009                                    Shotgun Wedding
# 4             48  587092                                       Unicorn Wars
# ...          ...     ...                                                ...
# 6836      101279  786413                                         Family 420
# 6835      101000  781582                     13rd Sister: Three Deadly Days
# 6834      100837  793730   Futari wa Precure Splash Star: Maji Doki Theater
# 6833      100698  728503  Tribe: The Untold Story of the Making of Vice ...
# 8077      177641  505142                                    Umutwe W'Inkuba
#
#                                           genres original_language  \
# 0                action-comedy-fantasy-adventure                en
# 1           action-science fiction-horror-comedy                en
# 2                          romance-action-comedy                en
# 3                          action-romance-comedy                en
# 4     action-animation-comedy-fantasy-horror-war                es
# ...                                          ...               ...
# 6836                         action-comedy-music                pa
# 6835                               comedy-action                vi
# 6834      animation-action-comedy-fantasy-family                ja
# 6833                         comedy-action-drama                en
# 8077                         action-drama-comedy                rn
#
#                                                overview  popularity  \
# 0     Billy Batson and his foster siblings who trans...        2011
# 1     An exploratory dive into the deepest depths of...        1321
# 2     Salt-of-the-earth Cole falls head over heels f...        1215
# 3     Darcy and Tom gather their families for the ul...        1043
# 4     An army of bear cubs train and indoctrinate yo...         536
# ...                                                 ...         ...
# 6836  A thriving indian family smokes a bunch of the...           1
# 6835  She thought she had overthrown the patron Hac ...           1
# 6834  A seed of hope descends from the sky landing a...           1
# 6833  Two brave young men set out to create the grea...           1
# 8077  The story is about a child who was rescued and...           1
#
#                                    production_companies release_date  \
# 0           New Line Cinema-The Safran Company-DC Films   2023-03-15
# 1     Apelles Entertainment-Warner Bros. Pictures-di...   2023-08-02
# 2                          Skydance Media-Apple Studios   2023-04-18
# 3     Lionsgate-Mandeville Films-Nuyorican Productio...   2022-12-28
# 4     UniKo-Schmuby Productions-Autour de Minuit-Pan...   2022-10-21
# ...                                                 ...          ...
# 6836                                           T-Series   2004-09-21
# 6835                                               <NA>   2020-12-25
# 6834                                     Toei Animation   2008-01-01
# 6833         Reel Green Pictures-Manuel Alejandro Films   2020-02-20
# 8077                                  BEC Entertainment   2018-05-26
#
#         budget  ...                                            credits  \
# 0    125000000  ...  Zachary Levi-Asher Angel-Jack Dylan Grazer-Rac...
# 1    129000000  ...  Jason Statham-Wu Jing-Shuya Sophia Cai-Sergio ...
# 2            0  ...  Chris Evans-Ana de Armas-Adrien Brody-Mike Moh...
# 3            0  ...  Jennifer Lopez-Josh Duhamel-Jennifer Coolidge-...
# 4            0  ...  Jon Goiri-Jaione Insausti-Ramón Barea-Txema Re...
# ...        ...  ...                                                ...
# 6836         0  ...               Dilawar Sidhu-Parvaz Kaur-Sabbu Deol
# 6835         0  ...  Thu Trang-Tiến Luật-Kiều Minh Tuấn-Trương Minh...
# 6834         0  ...  Orie Kimoto-Atsuko Enomoto-Kappei Yamaguchi-Mi...
# 6833      8000  ...  Thomas Burke-Xavier Alvarado-Manuel Alejandro ...
# 8077         0  ...  Issa Sadiki-Seif Sabushimike-Shifu Yves Ntiren...
#
#                                                keywords  \
# 0     superhero-end of the world-super power-aftercr...
# 1                   based on novel or book-sequel-kaiju
# 2                                          secret agent
# 3                             wedding-hostage situation
# 4                       gore-bear-unicorn-war-animation
# ...                                                 ...
# 6836                                               <NA>
# 6835                                               <NA>
# 6834                                      precure-anime
# 6833  movie business-gun-writing-satire-tribe-bloody...
# 8077                                               <NA>
#
#                            poster_path                     backdrop_path  \
# 0     /A3ZbZsmsvNGdprRi2lKgGEeVLEH.jpg  /nDxJJyA5giRhXx96q1sWbOUjMBI.jpg
# 1     /4m1Au3YkjqsxF8iwQy0fPYSxE0h.jpg  /Aukfa8dk6B5OxuelbaPBOJYXaBI.jpg
# 2     /liLN69YgoovHVgmlHJ876PKi5Yi.jpg  /b9UCfDzwiWw7mIFsIQR9ZJUeh7q.jpg
# 3     /t79ozwWnwekO0ADIzsFP1E5SkvR.jpg  /zGoZB4CboMzY1z4G3nU6BWnMDB2.jpg
# 4     /8KBj11zBaRdhoeq1q9jcAwKmDSk.jpg  /rbUPJoJJquPbX1AiV6GzOqcmJME.jpg
# ...                                ...                               ...
# 6836  /gbCp1EJDbKwH9N4L8mkE8GGJv5d.jpg                              <NA>
# 6835  /faqGzwnN6OWXDSiQQofFmMs2SBg.jpg                              <NA>
# 6834  /t2v4pA1klWMrOBrexO2Vk0PyvnL.jpg                              <NA>
# 6833  /9VmT16H0Qsswjr8vmjcRMM8l40z.jpg  /y6oFB4HfJTJg3CCBmvKDjTc6lgL.jpg
# 8077  /ja0z9i5Ws0MggB1LB6aPfRBNzUZ.jpg  /5fStwXStj7pmJMmwtRg14069FCk.jpg
#
#                                         recommendations  release_date_new  \
# 0     868759-994751-700391-948713-502356-938992-7660...        2023-03-15
# 1     447277-872585-346698-1083862-496450-457332-114...        2023-08-02
# 2                                         640146-726759        2023-04-18
# 3     702432-1064489-1013870-953734-805307-753965-84...        2022-12-28
# 4                                         852046-601796        2022-10-21
# ...                                                 ...               ...
# 6836                                               <NA>        2004-09-21
# 6835                                               <NA>        2020-12-25
# 6834                                               <NA>        2008-01-01
# 6833                                               <NA>        2020-02-20
# 8077                                               <NA>        2018-05-26
#
#      release_date_dt  year month day_of_week
# 0         2023-03-15  2023   Mar         Wed
# 1         2023-08-02  2023   Aug         Wed
# 2         2023-04-18  2023   Apr         Tue
# 3         2022-12-28  2022   Dec         Wed
# 4         2022-10-21  2022   Oct         Fri
# ...              ...   ...   ...         ...
# 6836      2004-09-21  2004   Sep         Tue
# 6835      2020-12-25  2020   Dec         Fri
# 6834      2008-01-01  2008   Jan         Tue
# 6833      2020-02-20  2020   Feb         Thu
# 8077      2018-05-26  2018   May         Sat
#
# [8078 rows x 26 columns]
